# %% [markdown]
# # Lacuna Masakhane Parts of Speech Classification Challenge
# # [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashatilov/zindi_masakhane_pos/blob/main/train.ipynb)

# %% [markdown]
# ## Load data and requirements

# %%
# get training data
# !git clone https://github.com/masakhane-io/masakhane-pos.git

# %%
# get training code
# !git clone https://github.com/ashatilov/zindi_masakhane_pos

# %%
# install requirements
# !pip install -r zindi_masakhane_pos/requirements.txt

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %% [markdown]
# ## 1st stage train on selected languages

# %%
# !python zindi_masakhane_pos/train.py --lora --languages "lug ibo mos sna kin"

# %%
# !zip -r preds_1.zip /content/<pred_folder>

# %%
# %tensorboard --logdir=.

# %% [markdown]
# ## 2nd stage train

# %% [markdown]
# The same training, but with added pseudo labels for luo and tsn from the 1st stage - it improves public score by ~0.01

# %%
# %tensorboard --logdir logs

# %%
# !python zindi_masakhane_pos/train.py --lora --languages "lug ibo mos sna kin" --pseudo_labels <path to csv with predicted labels>

# %%
# !zip -r preds_2.zip /content/<pred_folder>
